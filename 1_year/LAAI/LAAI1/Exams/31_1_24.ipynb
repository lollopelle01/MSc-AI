# %% [markdown]
# #  1

# %%
def new_update(D1,D2:dict):
    ks = []
    for k in D1:
        if k not in D2: 
            D2[k]=D1[k]
        else:
            ks.append(k)
    for k in ks:
        del D2[k]
        del D1[k]

# %% [markdown]
# # 2

# %%
def printgen(x):
    for e in list(x)[::-1]:
        print(e)

# %% [markdown]
# # 3

# %%
#do not insert print or tests

def partition(L):
    res = []
    Lc = L.copy()
    i = 0
    while Lc!=[] :
        e = min(Lc)
        Lc.remove(e)
        L[i] = e
        i += 1

# %%
def partition(L):
    p=L[0]
    init=1
    for j in range(1,len(L)):
        if L[j]<p:
            L[j],L[init]=L[init],L[j]
            init+=1
    L[0],L[init-1]=L[init-1],L[0]

# %% [markdown]
# # 4

# %%
#do not insert print or tests
class B(A):
    def __init__(self, n1, n2):
        super().__init__(n1)
        self.n2 = n2
    def __str__(self):
        return f"B: {self.xx*self.n2}"

# %% [markdown]
# # 5

# %%
import numpy as np

def filter_ones(A,B):
    return A[B.T==1].flatten()
