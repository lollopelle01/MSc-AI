# %% [markdown]
# # 1

# %%
A=4
#write your program as if the previous line was:
#A=int(input())

L=[2*i for i in range(A)]

# DO NOT MODIFY ANYTHING ELSE
def g(X):
    X.append(100)
    
g(L)

print(L)

# %% [markdown]
# # 2

# %%
class A:
    def __init__(self, xx): 
        self.__x = xx
    def get(self): 
        #INSERT HERE ONLY THE BODY OF get
        return self.__x
    def __str__(self):
        return str(self.get())

    
class B(A):
    pass

class C(B):
    def get(self):
        #INSERT HERE ONLY THE BODY OF get
        return super().get()
        
    #INSERT HERE YOUR OTHER METHOD DEFINITIONS, if needed
    def __add__(self, other):
        return C(self.get() + other.get())


#DO NOT MODIFY FROM HERE!
b=C(10)
c=C(20)
print(b+c)
b=C(70)
c=C(7)
print(b+c)

# %% [markdown]
# # 3

# %%
#do not insert print, or tests
#leave the following assignment unchanged
LL=[4, 0, 36, 28, 24, 20, 8, 16, 32, 16]

def is_constmod(L,k):
    for e in L:
        if e%k != 0 : return False
    return True

def constmod(L,k):
    if L==[] : return True
    if is_constmod(L,k): return True
    else :
        for i in range(len(L)):
            L[i] = (L[i]//k)*k
        return False

# %%
def constmod(L,k):
    ret=True
    for i in range(0,len(L)):
        if L[i]%k !=0:
            ret=False
            L[i] -= L[i]%k
    return ret

# %% [markdown]
# # 4

# %%
class SeqMod:
    def __init__(self,L):
        self.__LL=L
    #COMPLETE
    def get(self):
        return self.__LL

class Seqq(SeqMod):
    
    def is_constmod(self,k):
        L = self.get()
        for e in L:
            if e%k != 0 : return False
        return True
    
    def constmod(self,k):
        #COMPLETE
        L = self.get()
        if L==[] : pass
        if self.is_constmod(k): pass
        else :
            for i in range(len(L)):
                L[i] = (L[i]//k)*k
            pass
        
        
#DO NOT MODIFY FROM HERE
ob=Seqq([i*4 for i in range(10)])
ob.constmod(5)
print(ob.get())

# %% [markdown]
# # 5

# %%
import numpy as np

def modify(a, n):
    #insert only one line here
    a[a>n]+=sum(a[a<n])
    #end student code
    return a


a = np.array([[4, 5, 6], [7,8,9], [10, 11, 12], [17, 18, 19]])
